# %%
print("長庚大學\n醫學系\n陳沛筠")
# Out:
# 長庚大學
# 醫學系
# 陳沛筠

# %%
a = float(input("請輸入一個數字"))
print(a>10)
# Out:
# 請輸入一個數字2
# False

# %%
a = 3
b = 5
print(a**b)
# Out:
# 243

# %%
a = 3
b = 5
print(a!=b)
# Out:
# True

# %%
#Type1
a = 3
b = 5
a/=b
print(a)
#Type2
a = 3
b = 5
a = a/b
print(a)
# Out:
# 0.6
# 0.6
